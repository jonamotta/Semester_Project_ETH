# %%
import sys
import ROOT
import numpy as np
import pandas as pd
import root_pandas
import matplotlib.pyplot as plt
import uproot
# Out:
# Welcome to JupyROOT 6.16/00
# /Users/jonamotta/anaconda3/envs/python_root/lib/python2.7/site-packages/root_numpy/__init__.py:46: RuntimeWarning: numpy 1.16.3 is currently installed but you installed root_numpy against numpy 1.9.3. Please consider reinstalling root_numpy for this numpy version.
#   RuntimeWarning)

# %%
########################################
### READ TREES AND CREATE DATAFRAMES ###
########################################


# fix random seed for reproducibility
np.random.seed(1986)

features = [
    'mu_pt'     ,
    'mu_eta'    ,
    'mu_phi'    ,
    'mu_charge' ,
    'mu1_pt'    ,
    'mu1_eta'   ,
    'mu1_phi'   ,
    'mu1_charge',
    'mu2_pt'    ,
    'mu2_eta'   ,
    'mu2_phi'   ,
    'mu2_charge',
]

#create DataFrames with the values coming from the trees
file_tau = uproot.open('bc_jpsi_tau_nu_gen.root')
tree_tau = file_tau['tree;1']
tau  = tree_tau.pandas.df(tree_tau.keys())

file_mu = uproot.open('bc_jpsi_mu_nu_gen.root')
tree_mu = file_mu['tree;1']
mu  = tree_mu.pandas.df(tree_mu.keys())

# %%
print tree_tau.keys()
# Out:
# ['run', 'lumi', 'event', 'bc_pt', 'bc_eta', 'bc_phi', 'bc_charge', 'bc_mass', 'tau_pt', 'tau_eta', 'tau_phi', 'tau_charge', 'taunu_pt', 'taunu_eta', 'taunu_phi', 'mu_pt', 'mu_eta', 'mu_phi', 'mu_charge', 'munu_pt', 'munu_eta', 'munu_phi', 'jpsi_pt', 'jpsi_eta', 'jpsi_phi', 'jpsi_mass', 'mu1_pt', 'mu1_eta', 'mu1_phi', 'mu1_charge', 'mu2_pt', 'mu2_eta', 'mu2_phi', 'mu2_charge']

# %%
plt.hist(mu['mu_pt'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu_pt'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu pT[GeV]')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['mu_eta'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu_eta'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu eta')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['mu_phi'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu_phi'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu phi')
plt.ylabel('n_ev')
plt.show()

# %%
plt.hist(mu['mu1_pt'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu1_pt'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu1 pT[GeV]')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['mu1_eta'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu1_eta'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu1 eta')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['mu1_phi'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu1_phi'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu1 phi')
plt.ylabel('n_ev')
plt.show()

# %%
plt.hist(mu['mu2_pt'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu2_pt'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu2 pT[GeV]')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['mu2_eta'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu2_eta'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu2 eta')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['mu2_phi'], 100, facecolor='g', alpha=1.)
plt.hist(tau['mu2_phi'], 100, facecolor='r', alpha=.7)
plt.xlabel('mu2 phi')
plt.ylabel('n_ev')
plt.show()

# %%
plt.hist(mu['bc_pt'], 100, facecolor='g', alpha=1.)
plt.hist(tau['bc_pt'], 100, facecolor='r', alpha=.7)
plt.xlabel('bc pT[GeV]')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['bc_eta'], 100, facecolor='g', alpha=1.)
plt.hist(tau['bc_eta'], 100, facecolor='r', alpha=.7)
plt.xlabel('bc eta')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['bc_phi'], 100, facecolor='g', alpha=1.)
plt.hist(tau['bc_phi'], 100, facecolor='r', alpha=.7)
plt.xlabel('bc phi')
plt.ylabel('n_ev')
plt.show()

# %%
plt.hist(mu['jpsi_pt'], 100, facecolor='g', alpha=1.)
plt.hist(tau['jpsi_pt'], 100, facecolor='r', alpha=.7)
plt.xlabel('jpsi pT[GeV]')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['jpsi_eta'], 100, facecolor='g', alpha=1.)
plt.hist(tau['jpsi_eta'], 100, facecolor='r', alpha=.7)
plt.xlabel('jpsi eta')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['jpsi_phi'], 100, facecolor='g', alpha=1.)
plt.hist(tau['jpsi_phi'], 100, facecolor='r', alpha=.7)
plt.xlabel('jpsi phi')
plt.ylabel('n_ev')
plt.show()

# %%
plt.hist(mu['munu_pt'], 100, facecolor='g', alpha=1.)
plt.hist(tau['munu_pt'], 100, facecolor='r', alpha=.7)
plt.xlabel('munu pT[GeV]')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['munu_eta'], 100, facecolor='g', alpha=1.)
plt.hist(tau['munu_eta'], 100, facecolor='r', alpha=.7)
plt.xlabel('munu eta')
plt.ylabel('n_ev')
plt.show()

plt.hist(mu['munu_phi'], 100, facecolor='g', alpha=1.)
plt.hist(tau['munu_phi'], 100, facecolor='r', alpha=.7)
plt.xlabel('munu phi')
plt.ylabel('n_ev')
plt.show()

# %%
#there is no tau in the mu event

#plt.hist(mu['tau_pt'], 100, facecolor='g', alpha=1.)
plt.hist(tau['tau_pt'], 100, facecolor='r', alpha=1.)
plt.xlabel('tau pT[GeV]')
plt.ylabel('n_ev')
plt.show()

#plt.hist(mu['tau_eta'], 100, facecolor='g', alpha=1.)
plt.hist(tau['tau_eta'], 100, facecolor='r', alpha=1.)
plt.xlabel('tau eta')
plt.ylabel('n_ev')
plt.show()

#plt.hist(mu['tau_phi'], 100, facecolor='g', alpha=1.)
plt.hist(tau['tau_phi'], 100, facecolor='r', alpha=1.)
plt.xlabel('tau phi')
plt.ylabel('n_ev')
plt.show()

# %%
#there is no tau in the mu event

#plt.hist(mu['taunu_pt'], 100, facecolor='g', alpha=1.)
plt.hist(tau['taunu_pt'], 100, facecolor='r', alpha=1.)
plt.xlabel('taunu pT[GeV]')
plt.ylabel('n_ev')
plt.show()

#plt.hist(mu['taunu_eta'], 100, facecolor='g', alpha=1.)
plt.hist(tau['taunu_eta'], 100, facecolor='r', alpha=1.)
plt.xlabel('taunu eta')
plt.ylabel('n_ev')
plt.show()

#plt.hist(mu['taunu_phi'], 100, facecolor='g', alpha=1.)
plt.hist(tau['taunu_phi'], 100, facecolor='r', alpha=1.)
plt.xlabel('taunu phi')
plt.ylabel('n_ev')
plt.show()
